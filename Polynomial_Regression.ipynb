# %% [markdown]
# <a href="https://colab.research.google.com/github/harshesh/Self-Driving-Car/blob/master/Polynomial_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
# Out:
# Using TensorFlow backend.

# %%
np.random.seed(0)
points = 500
X = np.linspace(-3, 3, points)
y = np.sin(X) + np.random.uniform(-0.5, 0.5, points)
model = Sequential()
model.add(Dense(50, activation='sigmoid', input_dim=1))
model.add(Dense(30, activation='sigmoid'))
model.add(Dense(1))

# %%
adam = Adam(lr=0.01)
model.compile(loss='mse', optimizer=adam)
model.fit(X, y, epochs=50)
# Out:
# Epoch 1/50
# 500/500 [==============================] - 1s 1ms/step - loss: 0.4537
# Epoch 2/50
# 500/500 [==============================] - 0s 43us/step - loss: 0.2398
# Epoch 3/50
# 500/500 [==============================] - 0s 40us/step - loss: 0.2613
# Epoch 4/50
# 500/500 [==============================] - 0s 43us/step - loss: 0.2254
# Epoch 5/50
# 500/500 [==============================] - 0s 43us/step - loss: 0.2279
# Epoch 6/50
# 500/500 [==============================] - 0s 40us/step - loss: 0.2248
# Epoch 7/50
# 500/500 [==============================] - 0s 52us/step - loss: 0.2173
# Epoch 8/50
# 500/500 [==============================] - 0s 45us/step - loss: 0.2196
# Epoch 9/50
# 500/500 [==============================] - 0s 43us/step - loss: 0.2039
# Epoch 10/50
# 500/500 [==============================] - 0s 40us/step - loss: 0.1900
# Epoch 11/50
# 500/500 [==============================] - 0s 42us/step - loss: 0.1898
# Epoch 12/50
# ...

# %%
predictions = model.predict(X)
plt.scatter(X, y)
plt.plot(X, predictions, 'ro')
plt.show()
